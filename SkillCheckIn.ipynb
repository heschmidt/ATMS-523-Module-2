# %%
from dask.distributed import Client, progress
import dask

# %%
from dask.distributed import Client, progress
import dask

# %%
from dask.distributed import Client, progress
import dask

# %%
from dask.distributed import Client, progress
dask.config.set(temporary_directory='/tmp/snesbitt/dask-worker/')

# %%
client = Client()  # set up local cluster on your laptop
client
# Out:
# <Client: 'tcp://127.0.0.1:50078' processes=4 threads=8, memory=8.00 GiB>
# 2025-09-23 18:43:36,337 - distributed.nanny - WARNING - Restarting worker
# 2025-09-23 18:44:19,785 - distributed.nanny - WARNING - Restarting worker
# 2025-09-23 18:44:19,898 - distributed.nanny - WARNING - Restarting worker
# 2025-09-23 18:44:20,417 - distributed.nanny - WARNING - Restarting worker

# %%
import xarray as xr
import pandas as pd
import numpy as np

# %%
base_url = 'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/'
base_url2 = '/e5.moda.an.sfc.128_167_2t.ll025sc.'
base_url3 = '.nc'

# period of interest
pr = pd.date_range(start='1979-01',end='2022-12', freq='AS')

file_list=[]
for dt in pr:
    # get recent year and month
    year = dt.strftime('%Y')
    month = dt.strftime('%Y%m%d%H')
    month2 = (dt + pd.DateOffset(months=11)).strftime('%Y%m%d%H')

    # build complete file name
    single_file=(base_url+year+base_url2+month+'_'+month2+base_url3)
    file_list.append(single_file)
# Out:
# /var/folders/yn/jk_z3jjj5bq9hv1j210z7_800000gn/T/ipykernel_7369/2796436042.py:6: FutureWarning: 'AS' is deprecated and will be removed in a future version, please use 'YS' instead.
#   pr = pd.date_range(start='1979-01',end='2022-12', freq='AS')

# %%
file_list
# Out:
# ['https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1979/e5.moda.an.sfc.128_167_2t.ll025sc.1979010100_1979120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1980/e5.moda.an.sfc.128_167_2t.ll025sc.1980010100_1980120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1981/e5.moda.an.sfc.128_167_2t.ll025sc.1981010100_1981120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1982/e5.moda.an.sfc.128_167_2t.ll025sc.1982010100_1982120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1983/e5.moda.an.sfc.128_167_2t.ll025sc.1983010100_1983120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1984/e5.moda.an.sfc.128_167_2t.ll025sc.1984010100_1984120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1985/e5.moda.an.sfc.128_167_2t.ll025sc.1985010100_1985120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1986/e5.moda.an.sfc.128_167_2t.ll025sc.1986010100_1986120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1987/e5.moda.an.sfc.128_167_2t.ll025sc.1987010100_1987120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1988/e5.moda.an.sfc.128_167_2t.ll025sc.1988010100_1988120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1989/e5.moda.an.sfc.128_167_2t.ll025sc.1989010100_1989120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1990/e5.moda.an.sfc.128_167_2t.ll025sc.1990010100_1990120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1991/e5.moda.an.sfc.128_167_2t.ll025sc.1991010100_1991120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1992/e5.moda.an.sfc.128_167_2t.ll025sc.1992010100_1992120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1993/e5.moda.an.sfc.128_167_2t.ll025sc.1993010100_1993120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1994/e5.moda.an.sfc.128_167_2t.ll025sc.1994010100_1994120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1995/e5.moda.an.sfc.128_167_2t.ll025sc.1995010100_1995120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1996/e5.moda.an.sfc.128_167_2t.ll025sc.1996010100_1996120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1997/e5.moda.an.sfc.128_167_2t.ll025sc.1997010100_1997120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1998/e5.moda.an.sfc.128_167_2t.ll025sc.1998010100_1998120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1999/e5.moda.an.sfc.128_167_2t.ll025sc.1999010100_1999120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2000/e5.moda.an.sfc.128_167_2t.ll025sc.2000010100_2000120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2001/e5.moda.an.sfc.128_167_2t.ll025sc.2001010100_2001120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2002/e5.moda.an.sfc.128_167_2t.ll025sc.2002010100_2002120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2003/e5.moda.an.sfc.128_167_2t.ll025sc.2003010100_2003120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2004/e5.moda.an.sfc.128_167_2t.ll025sc.2004010100_2004120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2005/e5.moda.an.sfc.128_167_2t.ll025sc.2005010100_2005120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2006/e5.moda.an.sfc.128_167_2t.ll025sc.2006010100_2006120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2007/e5.moda.an.sfc.128_167_2t.ll025sc.2007010100_2007120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2008/e5.moda.an.sfc.128_167_2t.ll025sc.2008010100_2008120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2009/e5.moda.an.sfc.128_167_2t.ll025sc.2009010100_2009120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2010/e5.moda.an.sfc.128_167_2t.ll025sc.2010010100_2010120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2011/e5.moda.an.sfc.128_167_2t.ll025sc.2011010100_2011120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2012/e5.moda.an.sfc.128_167_2t.ll025sc.2012010100_2012120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2013/e5.moda.an.sfc.128_167_2t.ll025sc.2013010100_2013120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2014/e5.moda.an.sfc.128_167_2t.ll025sc.2014010100_2014120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2015/e5.moda.an.sfc.128_167_2t.ll025sc.2015010100_2015120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2016/e5.moda.an.sfc.128_167_2t.ll025sc.2016010100_2016120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2017/e5.moda.an.sfc.128_167_2t.ll025sc.2017010100_2017120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2018/e5.moda.an.sfc.128_167_2t.ll025sc.2018010100_2018120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2019/e5.moda.an.sfc.128_167_2t.ll025sc.2019010100_2019120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2020/e5.moda.an.sfc.128_167_2t.ll025sc.2020010100_2020120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2021/e5.moda.an.sfc.128_167_2t.ll025sc.2021010100_2021120100.nc',
#  'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/2022/e5.moda.an.sfc.128_167_2t.ll025sc.2022010100_2022120100.nc']

# %%
ds = xr.open_mfdataset(file_list, parallel=True,chunks={'time': '50MB'})
# Out:
# 2025-09-23 18:44:19,672 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-3e740745-b1a9-4117-8a56-7e47c7789613
# State:     executing
# Task:  <Task 'open_dataset-3e740745-b1a9-4117-8a56-7e47c7789613' open_dataset(..., ...)>
# Exception: "OSError(-90, 'NetCDF: file not found')"
# Traceback: '  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/api.py", line 687, in open_dataset\n    backend_ds = backend.open_dataset(\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 666, in open_dataset\n    store = NetCDF4DataStore.open(\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 452, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 393, in __init__\n    self.format = self.ds.data_model\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 461, in ds\n    return self._acquire()\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 455, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 135, in __enter__\n    return next(self.gen)\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n  File "src/netCDF4/_netCDF4.pyx", line 2521, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2158, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2025-09-23 18:44:19,673 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-efa56624-e002-4361-a282-30dfd26f5b6f
# State:     executing
# Task:  <Task 'open_dataset-efa56624-e002-4361-a282-30dfd26f5b6f' open_dataset(..., ...)>
# Exception: "OSError(-90, 'NetCDF: file not found')"
# Traceback: '  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/api.py", line 687, in open_dataset\n    backend_ds = backend.open_dataset(\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 666, in open_dataset\n    store = NetCDF4DataStore.open(\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 452, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 393, in __init__\n    self.format = self.ds.data_model\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 461, in ds\n    return self._acquire()\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py", line 455, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 135, in __enter__\n    return next(self.gen)\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n  File "/Users/Haley/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n  File "src/netCDF4/_netCDF4.pyx", line 2521, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2158, in netCDF4._netCDF4._ensure_nc_success\n'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in _acquire_with_cache_info()
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in __getitem__()
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1991/e5.moda.an.sfc.128_167_2t.ll025sc.1991010100_1991120100.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'b1cddfbc-8f42-4a14-8a50-5f73b7c96760']
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ds = xr.open_mfdataset(file_list, parallel=True,chunks={'time': '50MB'})
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/api.py:1643, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1638     datasets = [preprocess(ds) for ds in datasets]
#    1640 if parallel:
#    1641     # calling compute here will return the datasets/file_objs lists,
#    1642     # the underlying datasets will still be stored as dask arrays
# -> 1643     datasets, closers = dask.compute(datasets, closers)
#    1645 # Combine all datasets, closing them in case of a ValueError
#    1646 try:
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/dask/base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/api.py:687, in open_dataset()
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#     707 return ds
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:666, in open_dataset()
#     644 def open_dataset(
#     645     self,
#     646     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     663     autoclose=False,
#     664 ) -> Dataset:
#     665     filename_or_obj = _normalize_path(filename_or_obj)
# --> 666     store = NetCDF4DataStore.open(
#     667         filename_or_obj,
#     668         mode=mode,
#     669         format=format,
#     670         group=group,
#     671         clobber=clobber,
#     672         diskless=diskless,
#     673         persist=persist,
#     674         auto_complex=auto_complex,
#     675         lock=lock,
#     676         autoclose=autoclose,
#     677     )
#     679     store_entrypoint = StoreBackendEntrypoint()
#     680     with close_on_error(store):
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:452, in open()
#     448     kwargs["auto_complex"] = auto_complex
#     449 manager = CachingFileManager(
#     450     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     451 )
# --> 452 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:393, in __init__()
#     391 self._group = group
#     392 self._mode = mode
# --> 393 self.format = self.ds.data_model
#     394 self._filename = self.ds.filepath()
#     395 self.is_remote = is_remote_uri(self._filename)
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:461, in ds()
#     459 @property
#     460 def ds(self):
# --> 461     return self._acquire()
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:455, in _acquire()
#     454 def _acquire(self, needs_lock=True):
# --> 455     with self._manager.acquire_context(needs_lock) as root:
#     456         ds = _nc4_require_group(root, self._group, self._mode)
#     457     return ds
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py:135, in __enter__()
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py:199, in acquire_context()
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File ~/atms523/module-2-xarray-dask-and-the-cloud-heschmidt/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py:217, in _acquire_with_cache_info()
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2521, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2158, in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -90] NetCDF: file not found: 'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds633.1_nc/e5.moda.an.sfc/1991/e5.moda.an.sfc.128_167_2t.ll025sc.1991010100_1991120100.nc'

# %%
ds['VAR_2T'].sel(latitude=40., longitude=360-88., method='nearest').plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ds['VAR_2T'].sel(latitude=40., longitude=360-88., method='nearest').plot()
#
# NameError: name 'ds' is not defined

# %%
client.close()
